# %%
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.12/dist-packages (4.0.2)
# Requirement already satisfied: py4j<0.10.9.10,>=0.10.9.7 in /usr/local/lib/python3.12/dist-packages (from pyspark) (0.10.9.9)

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("RDDAssignment").getOrCreate()

sc = spark.sparkContext



emp_rdd = sc.parallelize([

    (101,"John","IT",50000),

    (102,"Alice","HR",60000),

    (103,"Bob","IT",70000),

    (104,"David","Finance",80000),

    (105,"Eva","HR",55000),

    (106,"Frank","IT",65000),

    (107,"Grace","Finance",90000),

    (108,"Helen","HR",62000)

])

# %% [markdown]
# ## Use map() to extract employee names.

# %%
rdd1 = emp_rdd.map(lambda x : x[1])# columns index
rdd1.collect()
# Out:
# ['John', 'Alice', 'Bob', 'David', 'Eva', 'Frank', 'Grace', 'Helen']

# %% [markdown]
# ## 2. Use map() to create (emp_id, salary) pairs.

# %%
rdd2 = emp_rdd.map(lambda x: (x[0],x[3]))
rdd2.collect()
# Out:
# [(101, 50000),
#  (102, 60000),
#  (103, 70000),
#  (104, 80000),
#  (105, 55000),
#  (106, 65000),
#  (107, 90000),
#  (108, 62000)]

# %% [markdown]
# ## 3. Use filter() to get employees with salary > 60000.

# %%
rdd3 = emp_rdd.filter(lambda x: x[3]>60000)
rdd3.collect()
# Out:
# [(103, 'Bob', 'IT', 70000),
#  (104, 'David', 'Finance', 80000),
#  (106, 'Frank', 'IT', 65000),
#  (107, 'Grace', 'Finance', 90000),
#  (108, 'Helen', 'HR', 62000)]

# %% [markdown]
# ## 4. Use filter() to get only IT department employees.

# %%
rdd4 = emp_rdd.filter(lambda x: x[2]=="IT")
rdd4.collect()
# Out:
# [(101, 'John', 'IT', 50000),
#  (103, 'Bob', 'IT', 70000),
#  (106, 'Frank', 'IT', 65000)]

# %% [markdown]
# ## 5. Use distinct() to find unique departments.

# %%
rdd5 = emp_rdd.map(lambda x: x[2]).distinct()
rdd5.collect()
# Out:
# ['IT', 'HR', 'Finance']

# %% [markdown]
# ## 6. Create another RDD and perform union().

# %%
emp_rddnew = sc.parallelize([

    (101,"John","IT",50000),

    (102,"Alice","HR",60000),

    (103,"Bob","IT",70000)
])

# %%
rdd6 = emp_rdd.union(emp_rddnew)
rdd6.collect()
# Out:
# [(101, 'John', 'IT', 50000),
#  (102, 'Alice', 'HR', 60000),
#  (103, 'Bob', 'IT', 70000),
#  (104, 'David', 'Finance', 80000),
#  (105, 'Eva', 'HR', 55000),
#  (106, 'Frank', 'IT', 65000),
#  (107, 'Grace', 'Finance', 90000),
#  (108, 'Helen', 'HR', 62000),
#  (101, 'John', 'IT', 50000),
#  (102, 'Alice', 'HR', 60000),
#  (103, 'Bob', 'IT', 70000)]

# %% [markdown]
# ## 7. Perform intersection() between two employee ID RDDs.

# %%
rdd7 = emp_rdd.intersection(emp_rddnew)
rdd7.collect()
# Out:
# [(101, 'John', 'IT', 50000),
#  (103, 'Bob', 'IT', 70000),
#  (102, 'Alice', 'HR', 60000)]

# %% [markdown]
# ## 8. Use flatMap() to split department names into characters.

# %%
rrd8=emp_rdd.flatMap(lambda x: x[2])
rrd8.collect()
# Out:
# ['I',
#  'T',
#  'H',
#  'R',
#  'I',
#  'T',
#  'F',
#  'i',
#  'n',
#  'a',
#  'n',
#  'c',
#  'e',
#  'H',
#  'R',
#  'I',
#  'T',
#  'F',
#  'i',
#  'n',
#  'a',
#  'n',
#  'c',
#  'e',
#  'H',
#  'R']

# %% [markdown]
# ##9. Use mapValues() on Pair RDD to increase salary by 10%.

# %%
rrd9=emp_rdd.map(lambda x : (x[0],x[3]))
rrd_newsal=rrd9.mapValues(lambda x : (x+(x*0.1)))
rrd_newsal.collect()
# Out:
# [(101, 55000.0),
#  (102, 66000.0),
#  (103, 77000.0),
#  (104, 88000.0),
#  (105, 60500.0),
#  (106, 71500.0),
#  (107, 99000.0),
#  (108, 68200.0)]

# %% [markdown]
# ## 10. Use reduceByKey() to calculate total salary by department.

# %%
rrd10=emp_rdd.map(lambda x : (x[2],x[3]))
rrd_dpt=rrd10.reduceByKey(lambda a,b : a+b)
rrd_dpt.collect()
# Out:
# [('IT', 185000), ('HR', 177000), ('Finance', 170000)]
